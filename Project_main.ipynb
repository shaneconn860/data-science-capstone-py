# %% [markdown]
# # Data Science Capstone Project - Solving Business Problems with Location Data

# %% [markdown]
# ## Table of Contents
#
# 1. Introduction/Business Problem
# 2. Data

# %% [markdown]
# ## Introduction/Business Problem
#
# For this project, we have been tasked with coming up with the best possible location for a company's first Cafe and Coffee Shop. The business owners have very ambitious plans for growth in the coming years as a result of their business acumen and experience in different hospitality ventures over the years. They have tasked us with coming up with an ideal location to open their business.
#
# They have identified the area of South Dublin to open their first location, for two main reasons. The first reason is that Dublin City Centre is so densely populated with coffee shops, cafes and restaurants that it is too competitive to flourish in such a competitive market, especially with a new and unknown brand. It should noted that the business owners are open to locations immediately outside the city on the South side.
#
# The second reason is that South Dublin is considered a very wealthy and affluent area. It is the assumption of the business owners that if they can provide a leading service and quality of product, that the inhabitants of the South side of the River Liffey will spend more money and keep coming back. They hope that this location will be the first of many; once they develop the brand here, they can then branch out in to the city centre with a better-known brand and quality of coffee.
#
# Further to the South of the city being an ideal area to start this business, it is on the coastal area of the South where the quality of life is higher. This area also boasts the DART (Dublin Area Rapid Transit) Railway network leading in to the city and so the owners would ideally like to open a location close to one of these stations, hoping to attract early-morning commuters as well as catering for a lunchtime crowd. In order to identify the primary location for the first outlet, we need to take in to account the amount of competitor outlets that are already operating there, while also exploring if there are many shops and other services in the area. We will achieve this by utilizing the FourSquare API to return such locations.

# %% [markdown]
# ## Data
#
# ### **Part 1:**

# %% [markdown]
# Before we do any data preprocessing, let's install the packages that we will need throughout this project.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

# %% [markdown]
# The first part of our data process will be to obtain the list of DART stations on the Dublin Southside. One such list can be found [here](https://data.smartdublin.ie/dataset/dlr-dart-stations/resource/db0ff728-884e-40c0-9e3c-e13344d00dfc). After reading in this file and inspecting the data it seems that the X and Y coordinates are incorrect for the city of Dublin so we will need to ascertain the correct coordinates using the Nominatim feature of the geopy package at a later step. For now though we will remove these columns along with the column named *stop_id* as there is no use for it during this process.

# %%
# Read in csv file and inspect the first few rows

filename = "https://data.smartdublin.ie/dataset/3d15a715-0dc3-416a-a2c7-71534494efdc/resource/db0ff728-884e-40c0-9e3c-e13344d00dfc/download/dlr_east_coast_dart_stations.csv"
df = pd.read_csv(filename)
df.head()
# Out:
#    X_Coord   Y_Coord     stop_id                    stop_name
# 0   716232  734404.0  825GA00065    Tara Street Train Station
# 1   716699  735015.0  825GA00167       Connolly Train Station
# 2   717213  734847.0  825GA00184      Docklands Train Station
# 3   716656  733978.0  825GA00204         Pearse Train Station
# 4   719156  731539.0  825GA00079  Sydney Parade Train Station

# %%
# Remove unwanted columns

df = df.drop(df.columns[[0, 1, 2]], axis=1)
df.head()
# Out:
#                      stop_name
# 0    Tara Street Train Station
# 1       Connolly Train Station
# 2      Docklands Train Station
# 3         Pearse Train Station
# 4  Sydney Parade Train Station

# %% [markdown]
# The second issue with the dataset is that it there are duplicate rows. We only want rows 0-18 so we need to remove the duplicates.

# %%
# Remove duplicate rows across the dataframe

df = df.drop_duplicates()
df
# Out:
#                                 stop_name
# 0               Tara Street Train Station
# 1                  Connolly Train Station
# 2                 Docklands Train Station
# 3                    Pearse Train Station
# 4             Sydney Parade Train Station
# 5                  Shankill Train Station
# 6                  Seapoint Train Station
# 7                Sandymount Train Station
# 8                Glenageary Train Station
# 9   Sandycove and Glasthule Train Station
# 10   Salthill and Monkstown Train Station
# 11                Blackrock Train Station
# 12              Booterstown Train Station
# 13                   Dalkey Train Station
# 14            Dun Laoghaire Train Station
# 15           Lansdowne Road Train Station
# 16         Grand Canal Dock Train Station
# 17                 Killiney Train Station
# 18                     Bray Train Station

# %% [markdown]
# The next step in the process is to replace the words *Train Station* with the string *, Dublin* so that the locations can be correctly picked up when we fetch the coordinates using geopy.

# %%
# Replace part of string with another

df = df.replace({'Train Station':', Dublin'}, regex=True)
df
# Out:
#                            stop_name
# 0               Tara Street , Dublin
# 1                  Connolly , Dublin
# 2                 Docklands , Dublin
# 3                    Pearse , Dublin
# 4             Sydney Parade , Dublin
# 5                  Shankill , Dublin
# 6                  Seapoint , Dublin
# 7                Sandymount , Dublin
# 8                Glenageary , Dublin
# 9   Sandycove and Glasthule , Dublin
# 10   Salthill and Monkstown , Dublin
# 11                Blackrock , Dublin
# 12              Booterstown , Dublin
# 13                   Dalkey , Dublin
# 14            Dun Laoghaire , Dublin
# 15           Lansdowne Road , Dublin
# 16         Grand Canal Dock , Dublin
# 17                 Killiney , Dublin
# 18                     Bray , Dublin

# %% [markdown]
# Next we export the sole remaining column (stop_name) to a list so that we can use it in a for loop and append to the new dataframe that we create.

# %%
# Export entire column to a workable list for looping purposes

stations1 = df['stop_name'].tolist()
stations1
# Out:
# ['Tara Street , Dublin',
#  'Connolly , Dublin',
#  'Docklands , Dublin',
#  'Pearse , Dublin',
#  'Sydney Parade , Dublin',
#  'Shankill , Dublin',
#  'Seapoint , Dublin',
#  'Sandymount , Dublin',
#  'Glenageary , Dublin',
#  'Sandycove and Glasthule , Dublin',
#  'Salthill and Monkstown , Dublin',
#  'Blackrock , Dublin',
#  'Booterstown , Dublin',
#  'Dalkey , Dublin',
#  'Dun Laoghaire , Dublin',
#  'Lansdowne Road , Dublin',
#  'Grand Canal Dock , Dublin',
#  'Killiney , Dublin',
#  'Bray , Dublin']

# %% [markdown]
# We then create the empty dataframe called *stations* with the column names *station* (replacing stop_name), *latitude* and *longitude*.

# %%
# Create a variable to store column names

column_names = ['Station', 'Latitude', 'Longitude'] 

# Create blank with dataframe using the previously-created column names

stations = pd.DataFrame(columns=column_names)

# %% [markdown]
# After supplying the list of stops to the geopy function, we obtain the correct coordinates for each of the stations and then append these along with the station names to our new dataframe.

# %%
# Loop through the list appending station name and coordinates obtained from geolocator in to stations dataframe

for i in stations1:
    geolocator = Nominatim(user_agent="ny_explorer")
    location = geolocator.geocode(i)
    latitude = location.latitude
    longitude = location.longitude
    stations = stations.append({'Station': i,
                                        'Latitude': latitude,
                                        'Longitude': longitude}, ignore_index=True)
    
    
stations
# Out:
#                              Station   Latitude  Longitude
# 0               Tara Street , Dublin  53.347063  -6.254314
# 1                  Connolly , Dublin  53.350949  -6.249872
# 2                 Docklands , Dublin  53.353666  -6.228333
# 3                    Pearse , Dublin  53.343335  -6.248463
# 4             Sydney Parade , Dublin  53.320787  -6.211552
# 5                  Shankill , Dublin  53.230228  -6.124181
# 6                  Seapoint , Dublin  53.466102  -6.191389
# 7                Sandymount , Dublin  53.327928  -6.221050
# 8                Glenageary , Dublin  53.281238  -6.123108
# 9   Sandycove and Glasthule , Dublin  53.288252  -6.127045
# 10   Salthill and Monkstown , Dublin  53.295391  -6.152424
# 11                Blackrock , Dublin  53.301864  -6.178834
# 12              Booterstown , Dublin  53.308629  -6.196652
# 13                   Dalkey , Dublin  53.275624  -6.103204
# 14            Dun Laoghaire , Dublin  53.292279  -6.136008
# 15           Lansdowne Road , Dublin  53.335233  -6.228178
# 16         Grand Canal Dock , Dublin  53.339819  -6.238188
# 17                 Killiney , Dublin  53.255384  -6.113040
# 18                     Bray , Dublin  53.203912  -6.232220

# %% [markdown]
# We want to tidy our dataset a little further by removing stations Tara St, Connolly and Docklands as these are deemed to be in the city centre and not a location we are interested in.

# %%
# Remove certain rows from the dataset

stations2 = stations[~stations.Station.isin(['Tara Street , Dublin', 'Connolly , Dublin', 
                                          'Docklands , Dublin'])]

stations2
# Out:
#                              Station   Latitude  Longitude
# 3                    Pearse , Dublin  53.343335  -6.248463
# 4             Sydney Parade , Dublin  53.320787  -6.211552
# 5                  Shankill , Dublin  53.230228  -6.124181
# 6                  Seapoint , Dublin  53.466102  -6.191389
# 7                Sandymount , Dublin  53.327928  -6.221050
# 8                Glenageary , Dublin  53.281238  -6.123108
# 9   Sandycove and Glasthule , Dublin  53.288252  -6.127045
# 10   Salthill and Monkstown , Dublin  53.295391  -6.152424
# 11                Blackrock , Dublin  53.301864  -6.178834
# 12              Booterstown , Dublin  53.308629  -6.196652
# 13                   Dalkey , Dublin  53.275624  -6.103204
# 14            Dun Laoghaire , Dublin  53.292279  -6.136008
# 15           Lansdowne Road , Dublin  53.335233  -6.228178
# 16         Grand Canal Dock , Dublin  53.339819  -6.238188
# 17                 Killiney , Dublin  53.255384  -6.113040
# 18                     Bray , Dublin  53.203912  -6.232220

# %% [markdown]
# ### **Part 2:**
#
# The second part of the data process is to utilize the FourSquare API to get a list of competing businesses in the areas we want to explore. Firstly, we must define our API credentials.

# %%
# Define API credentials

CLIENT_ID = 'S220GACGVSNRKG1XWRUG4GGR0UEJ5P2IHQF3KFGSDDK15ADK' # Foursquare ID
CLIENT_SECRET = 'ULHQFM5ED0KBFZH4Y04XUON2Y2OBQJ2423OCHWWMQ30UAYS4' # Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# We call the [venues endpoint](https://developer.foursquare.com/docs/places-api/endpoints/) and obtain the venue name, coordinates and the type of business it is and associate them with the stations that we have defined in Part 1.

# %%
# Create URL

LIMIT = 1000 # limit of number of venues returned by Foursquare API

radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=S220GACGVSNRKG1XWRUG4GGR0UEJ5P2IHQF3KFGSDDK15ADK&client_secret=ULHQFM5ED0KBFZH4Y04XUON2Y2OBQJ2423OCHWWMQ30UAYS4&v=20180605&ll=53.203912,-6.2322203&radius=500&limit=1000'

# %%
# Obtain nearby venues to the stations from FourSquare

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['station', 
                  'station_latitude', 
                  'station_longitude', 
                  'venue', 
                  'venue_latitude', 
                  'venue_longitude', 
                  'venue_category']
    
    return(nearby_venues)

# %% [markdown]
# Once that is done we create a new dataframe combining venue and original information.

# %%
# Create new dataframe with updated venue information

dublin_venues = getNearbyVenues(names=stations2['Station'],
                                   latitudes=stations2['Latitude'],
                                  longitudes=stations2['Longitude'])
# Out:
# Pearse , Dublin
# Sydney Parade , Dublin
# Shankill , Dublin
# Seapoint , Dublin
# Sandymount , Dublin
# Glenageary , Dublin
# Sandycove and Glasthule , Dublin
# Salthill and Monkstown , Dublin
# Blackrock , Dublin
# Booterstown , Dublin
# Dalkey , Dublin
# Dun Laoghaire , Dublin
# Lansdowne Road , Dublin
# Grand Canal Dock , Dublin
# Killiney , Dublin
# Bray , Dublin

# %% [markdown]
# Let's print the number of rows and columns and inspect the first 20 rows

# %%
# Print the number of rows and columns

print(dublin_venues.shape)

# Inspect the first 20 rows

dublin_venues.head(20)
# Out:
# (286, 7)
#             station  station_latitude  station_longitude  \
# 0   Pearse , Dublin         53.343335          -6.248463
# 1   Pearse , Dublin         53.343335          -6.248463
# 2   Pearse , Dublin         53.343335          -6.248463
# 3   Pearse , Dublin         53.343335          -6.248463
# 4   Pearse , Dublin         53.343335          -6.248463
# 5   Pearse , Dublin         53.343335          -6.248463
# 6   Pearse , Dublin         53.343335          -6.248463
# 7   Pearse , Dublin         53.343335          -6.248463
# 8   Pearse , Dublin         53.343335          -6.248463
# 9   Pearse , Dublin         53.343335          -6.248463
# 10  Pearse , Dublin         53.343335          -6.248463
# 11  Pearse , Dublin         53.343335          -6.248463
# 12  Pearse , Dublin         53.343335          -6.248463
# 13  Pearse , Dublin         53.343335          -6.248463
# 14  Pearse , Dublin         53.343335          -6.248463
# 15  Pearse , Dublin         53.343335          -6.248463
# 16  Pearse , Dublin         53.343335          -6.248463
# 17  Pearse , Dublin         53.343335          -6.248463
# 18  Pearse , Dublin         53.343335          -6.248463
# 19  Pearse , Dublin         53.343335          -6.248463
#
#                           venue  venue_latitude  venue_longitude  \
# 0               Science Gallery       53.344186        -6.250524
# 1                      Bread 41       53.344812        -6.251619
# 2            Oscar Wilde Statue       53.340937        -6.250692
# 3          Science Gallery Café       53.344348        -6.250779
# 4                 Honey Truffle       53.344089        -6.248893
# 5              Sweny's Pharmacy       53.341910        -6.250392
# 6           Merrion Square Park       53.340138        -6.250451
# 7          Arabica Coffee House       53.343676        -6.247063
# 8        Probus Wines & Spirits       53.341578        -6.248789
# 9                The Ginger Man       53.341859        -6.249580
# 10                The Pavillion       53.342741        -6.252955
# 11  National Gallery of Ireland       53.341558        -6.252528
# 12                  Coffeeangel       53.342071        -6.254019
# 13            Offbeat Donut Co.       53.343752        -6.249548
# 14             The Gallery Café       53.341766        -6.252516
# 15                     The Alex       53.341801        -6.249048
# 16                     Gertrude       53.343172        -6.243476
# 17                Lolly & Cooks       53.341090        -6.245572
# 18                Pearse Square       53.343367        -6.241793
# 19      Perpetua Fitness Dublin       53.344896        -6.243571
#
#        venue_category
# 0      Science Museum
# 1              Bakery
# 2   Outdoor Sculpture
# 3         Coffee Shop
# 4         Coffee Shop
# 5           Bookstore
# 6                Park
# 7         Coffee Shop
# 8           Wine Shop
# 9                 Pub
# 10                Bar
# 11         Art Museum
# 12        Coffee Shop
# 13         Donut Shop
# 14               Café
# 15              Hotel
# 16         Restaurant
# 17               Café
# 18              Plaza
# 19                Gym

# %% [markdown]
# Upon inspecting the data we see that not all Train stations are picked up by the FourSquare location data. There are only 10 whereas there should be 17 in total.

# %%
trains = dublin_venues[dublin_venues.venue_category.isin(['Train Station', 'Light Rail Station'])]
trains
# Out:
#                               station  station_latitude  station_longitude  \
# 33             Sydney Parade , Dublin         53.320787          -6.211552
# 55                Sandymount , Dublin         53.327928          -6.221050
# 68                Glenageary , Dublin         53.281238          -6.123108
# 86   Sandycove and Glasthule , Dublin         53.288252          -6.127045
# 101   Salthill and Monkstown , Dublin         53.295391          -6.152424
# 120                Blackrock , Dublin         53.301864          -6.178834
# 134              Booterstown , Dublin         53.308629          -6.196652
# 226           Lansdowne Road , Dublin         53.335233          -6.228178
# 279         Grand Canal Dock , Dublin         53.339819          -6.238188
# 283                 Killiney , Dublin         53.255384          -6.113040
#
#                                   venue  venue_latitude  venue_longitude  \
# 33           Sydney Parade DART Station       53.320489        -6.211176
# 55              Sandymount DART Station       53.328439        -6.223726
# 68              Glenageary Dart Station       53.281148        -6.122844
# 86   Sandycove & Glasthule Dart Station       53.287980        -6.127124
# 101   Salthill & Monkstown DART Station       53.295372        -6.152205
# 120              Blackrock Dart Station       53.302744        -6.178733
# 134            Booterstown DART Station       53.310137        -6.195415
# 226         Lansdowne Road DART Station       53.333999        -6.228834
# 279    Grand Canal Dock Railway Station       53.339532        -6.237297
# 283            Killiney Railway Station       53.255588        -6.113045
#
#          venue_category
# 33        Train Station
# 55   Light Rail Station
# 68        Train Station
# 86        Train Station
# 101       Train Station
# 120       Train Station
# 134       Train Station
# 226       Train Station
# 279       Train Station
# 283       Train Station

# %% [markdown]
# We need to create a new dataframe with those stations and their coordinates and merge them with our main dataframe.

# %%
# Read in csv of missing stations

missing_stations = pd.read_csv('https://raw.githubusercontent.com/shaneconn860/data-science-capstone-py/master/extra_stations.csv')
missing_stations
# Out:
#                  station  station_latitude  station_longitude  \
# 0           Bray, Dublin         53.204520          -6.100993
# 1       Seapoint, Dublin         53.299106          -6.165473
# 2         Pearse, Dublin         53.343327          -6.248315
# 3      Shankhill, Dublin         53.236508          -6.117142
# 4     Glenageary, Dublin         53.281183          -6.123090
# 5  Dun Laoghaire, Dublin         53.294900          -6.134548
# 6         Dalkey, Dublin         53.275800          -6.103300
#
#                     venue  venue_latitude  venue_longitude venue_category
# 0       Bray Daly Station       53.204520        -6.100993  Train Station
# 1  Seapoint Train Station       53.299106        -6.165473  Train Station
# 2          Pearse Station       53.343327        -6.248315  Train Station
# 3       Shankhill Station       53.236508        -6.117142  Train Station
# 4      Glenageary Station       53.281183        -6.123090  Train Station
# 5   Dun Laoghaire Station       53.294900        -6.134548  Train Station
# 6          Dalkey Station       53.275800        -6.103300  Train Station

# %%
# Concatenate missing stations with main dataframe

dublin_venues2 = pd.concat([dublin_venues, missing_stations])

# %%
# View number of rows to verify increase

print(dublin_venues2.shape)
# Out:
# (293, 7)

# %%
dublin_venues2.to_csv('venues.csv')

# %% [markdown]
# The rows have increased by 7 so we are happy with the dataset. Overall we now have our raw dataset and are ready to start exploring the data to analyze and select the best possible location for our first location.

# %% [markdown]
# ## Methodology
#
# ### Analysis

# %% [markdown]
# We want to have a look at the list of business types as we may want to locate the business in an area where there are shopping centres, department stores or other amenities. Facilities in these areas indicate there would be a certain level of foot traffic meaning there should be more people around to enjoy a cup of coffee or a tasty sandwich during the normal hours of business.

# %%
# Get list of venue types and count them

dublin_venues2['venue_category'].value_counts()
# Out:
# Café                       26
# Pub                        25
# Coffee Shop                24
# Hotel                      18
# Train Station              16
# Bar                        10
# Italian Restaurant         10
# Restaurant                  9
# Supermarket                 6
# Park                        5
# Farmers Market              5
# Bakery                      5
# Gastropub                   5
# Gym                         5
# Plaza                       4
# Chinese Restaurant          4
# Breakfast Spot              4
# Pizza Place                 4
# Steakhouse                  3
# Fish & Chips Shop           3
# Ice Cream Shop              3
# Wine Shop                   3
# Fast Food Restaurant        3
# Deli / Bodega               3
# Gourmet Shop                3
# Shopping Mall               3
# Scenic Lookout              3
# Gym / Fitness Center        3
# Sports Bar                  2
# Hotel Bar                   2
# Bookstore                   2
# Bistro                      2
# Salad Place                 2
# Museum                      2
# Grocery Store               2
# Beach                       2
# Diner                       2
# Rugby Pitch                 2
# Playground                  2
# Theater                     2
# Convenience Store           2
# Seafood Restaurant          2
# Food & Drink Shop           2
# Burger Joint                2
# Sandwich Place              2
# Furniture / Home Store      2
# Historic Site               2
# Candy Store                 2
# Japanese Restaurant         2
# Spa                         2
# Indian Restaurant           2
# Clothing Store              1
# Department Store            1
# Pharmacy                    1
# Donut Shop                  1
# Hockey Field                1
# Flea Market                 1
# Comfort Food Restaurant     1
# Cricket Ground              1
# Castle                      1
# Light Rail Station          1
# Nail Salon                  1
# Waterfront                  1
# Cocktail Bar                1
# Pool                        1
# Fish Market                 1
# Soccer Field                1
# Fountain                    1
# Soccer Stadium              1
# Health Food Store           1
# Yoga Studio                 1
# Movie Theater               1
# Asian Restaurant            1
# Lingerie Store              1
# River                       1
# Food Truck                  1
# Art Museum                  1
# Bus Stop                    1
# Outdoor Sculpture           1
# Sushi Restaurant            1
# Thai Restaurant             1
# Recording Studio            1
# Science Museum              1
# Name: venue_category, dtype: int64

# %% [markdown]
# We see from this list the types of businesses and public amenities we want to include in our exploration. These are:
#
# - Plaza
# - Shopping Mall
# - Department Store
# - Clothing Store
# - Waterfront
# - Science Museum
# - Art Museum
# - Museum
# - Flea Market
# - Market
# - Nail Salon
# - Yoga Studio
# - Playground
#
# We can now refine our data even further by selecting only these venues along with cafes, coffee shops and sandwich places as these our the types of labels that are business will be associated with. We also add the train stations to this query to ensure all of our stations are picked up.

# %%
# Return only venues that we specifically define

dub3 = dublin_venues2[dublin_venues2.venue_category.isin(['Train Station', 'Light Rail Station',
                                                'Café', 'Coffee Shop', 'Sandwich Place', 'Plaza',
                                                       'Shopping Mall', 'Department Store', 'Clothing Store',
                                                       'Waterfront', 'Science Museum', 'Art Museum',
                                                       'Museum', 'Flea Market', 'Market', 'Nail Salon', 'Yoga Studio', 'Playground'])]
dub3
# Out:
#                               station  station_latitude  station_longitude  \
# 0                     Pearse , Dublin         53.343335          -6.248463
# 3                     Pearse , Dublin         53.343335          -6.248463
# 4                     Pearse , Dublin         53.343335          -6.248463
# 7                     Pearse , Dublin         53.343335          -6.248463
# 11                    Pearse , Dublin         53.343335          -6.248463
# 12                    Pearse , Dublin         53.343335          -6.248463
# 14                    Pearse , Dublin         53.343335          -6.248463
# 17                    Pearse , Dublin         53.343335          -6.248463
# 18                    Pearse , Dublin         53.343335          -6.248463
# 28                    Pearse , Dublin         53.343335          -6.248463
# 30                    Pearse , Dublin         53.343335          -6.248463
# 31                    Pearse , Dublin         53.343335          -6.248463
# 32             Sydney Parade , Dublin         53.320787          -6.211552
# 33             Sydney Parade , Dublin         53.320787          -6.211552
# 34             Sydney Parade , Dublin         53.320787          -6.211552
# 40                  Shankill , Dublin         53.230228          -6.124181
# 45                  Shankill , Dublin         53.230228          -6.124181
# 52                Sandymount , Dublin         53.327928          -6.221050
# 55                Sandymount , Dublin         53.327928          -6.221050
# 68                Glenageary , Dublin         53.281238          -6.123108
# 70   Sandycove and Glasthule , Dublin         53.288252          -6.127045
# 80   Sandycove and Glasthule , Dublin         53.288252          -6.127045
# 81   Sandycove and Glasthule , Dublin         53.288252          -6.127045
# 83   Sandycove and Glasthule , Dublin         53.288252          -6.127045
# 84   Sandycove and Glasthule , Dublin         53.288252          -6.127045
# 86   Sandycove and Glasthule , Dublin         53.288252          -6.127045
# 88   Sandycove and Glasthule , Dublin         53.288252          -6.127045
# 93    Salthill and Monkstown , Dublin         53.295391          -6.152424
# 101   Salthill and Monkstown , Dublin         53.295391          -6.152424
# 105                Blackrock , Dublin         53.301864          -6.178834
# 107                Blackrock , Dublin         53.301864          -6.178834
# 110                Blackrock , Dublin         53.301864          -6.178834
# 113                Blackrock , Dublin         53.301864          -6.178834
# 114                Blackrock , Dublin         53.301864          -6.178834
# 115                Blackrock , Dublin         53.301864          -6.178834
# 120                Blackrock , Dublin         53.301864          -6.178834
# 122                Blackrock , Dublin         53.301864          -6.178834
# 123                Blackrock , Dublin         53.301864          -6.178834
# 125                Blackrock , Dublin         53.301864          -6.178834
# 127                Blackrock , Dublin         53.301864          -6.178834
# 132              Booterstown , Dublin         53.308629          -6.196652
# 134              Booterstown , Dublin         53.308629          -6.196652
# 141                   Dalkey , Dublin         53.275624          -6.103204
# 144                   Dalkey , Dublin         53.275624          -6.103204
# 151                   Dalkey , Dublin         53.275624          -6.103204
# 167            Dun Laoghaire , Dublin         53.292279          -6.136008
# 171            Dun Laoghaire , Dublin         53.292279          -6.136008
# 173            Dun Laoghaire , Dublin         53.292279          -6.136008
# 175            Dun Laoghaire , Dublin         53.292279          -6.136008
# 176            Dun Laoghaire , Dublin         53.292279          -6.136008
# 187            Dun Laoghaire , Dublin         53.292279          -6.136008
# 188            Dun Laoghaire , Dublin         53.292279          -6.136008
# 191            Dun Laoghaire , Dublin         53.292279          -6.136008
# 193            Dun Laoghaire , Dublin         53.292279          -6.136008
# 194            Dun Laoghaire , Dublin         53.292279          -6.136008
# 195            Dun Laoghaire , Dublin         53.292279          -6.136008
# 197            Dun Laoghaire , Dublin         53.292279          -6.136008
# 203            Dun Laoghaire , Dublin         53.292279          -6.136008
# 207           Lansdowne Road , Dublin         53.335233          -6.228178
# 211           Lansdowne Road , Dublin         53.335233          -6.228178
# 214           Lansdowne Road , Dublin         53.335233          -6.228178
# 215           Lansdowne Road , Dublin         53.335233          -6.228178
# 218           Lansdowne Road , Dublin         53.335233          -6.228178
# 220           Lansdowne Road , Dublin         53.335233          -6.228178
# 226           Lansdowne Road , Dublin         53.335233          -6.228178
# 231           Lansdowne Road , Dublin         53.335233          -6.228178
# 234         Grand Canal Dock , Dublin         53.339819          -6.238188
# 236         Grand Canal Dock , Dublin         53.339819          -6.238188
# 239         Grand Canal Dock , Dublin         53.339819          -6.238188
# 244         Grand Canal Dock , Dublin         53.339819          -6.238188
# 245         Grand Canal Dock , Dublin         53.339819          -6.238188
# 246         Grand Canal Dock , Dublin         53.339819          -6.238188
# 248         Grand Canal Dock , Dublin         53.339819          -6.238188
# 258         Grand Canal Dock , Dublin         53.339819          -6.238188
# 261         Grand Canal Dock , Dublin         53.339819          -6.238188
# 267         Grand Canal Dock , Dublin         53.339819          -6.238188
# 268         Grand Canal Dock , Dublin         53.339819          -6.238188
# 269         Grand Canal Dock , Dublin         53.339819          -6.238188
# 277         Grand Canal Dock , Dublin         53.339819          -6.238188
# 279         Grand Canal Dock , Dublin         53.339819          -6.238188
# 283                 Killiney , Dublin         53.255384          -6.113040
# 0                        Bray, Dublin         53.204520          -6.100993
# 1                    Seapoint, Dublin         53.299106          -6.165473
# 2                      Pearse, Dublin         53.343327          -6.248315
# 3                   Shankhill, Dublin         53.236508          -6.117142
# 4                  Glenageary, Dublin         53.281183          -6.123090
# 5               Dun Laoghaire, Dublin         53.294900          -6.134548
# 6                      Dalkey, Dublin         53.275800          -6.103300
#
#                                    venue  venue_latitude  venue_longitude  \
# 0                        Science Gallery       53.344186        -6.250524
# 3                   Science Gallery Café       53.344348        -6.250779
# 4                          Honey Truffle       53.344089        -6.248893
# 7                   Arabica Coffee House       53.343676        -6.247063
# 11           National Gallery of Ireland       53.341558        -6.252528
# 12                           Coffeeangel       53.342071        -6.254019
# 14                      The Gallery Café       53.341766        -6.252516
# 17                         Lolly & Cooks       53.341090        -6.245572
# 18                         Pearse Square       53.343367        -6.241793
# 28                Angel Park Café & Deli       53.339326        -6.245574
# 30                              Gerard's       53.346527        -6.244675
# 31                      The Pig & Heifer       53.347207        -6.249742
# 32                       Fiji Coffee Bar       53.318807        -6.213844
# 33            Sydney Parade DART Station       53.320489        -6.211176
# 34                  Sandymount Promenade       53.318539        -6.205810
# 40                              One Deli       53.226047        -6.124464
# 45            Shankill Barbequeue Centre       53.226089        -6.124621
# 52                       The Orange Goat       53.330452        -6.225113
# 55               Sandymount DART Station       53.328439        -6.223726
# 68               Glenageary Dart Station       53.281148        -6.122844
# 70                                 Hatch       53.287396        -6.124791
# 80                               64 Wine       53.287062        -6.123200
# 81                         Cookbook Café       53.287136        -6.122783
# 83                      Missy Moops Cafe       53.289864        -6.130340
# 84                       Leonardo Coffee       53.290530        -6.132157
# 86    Sandycove & Glasthule Dart Station       53.287980        -6.127124
# 88              People's Park Playground       53.289850        -6.127715
# 93                       Café du Journal       53.293869        -6.151043
# 101    Salthill & Monkstown DART Station       53.295372        -6.152205
# 105                   Bear Market Coffee       53.301465        -6.177552
# 107                       The Mellow Fig       53.301578        -6.178684
# 110                      Marks & Spencer       53.301127        -6.182080
# 113                            News Cafe       53.299735        -6.175252
# 114                     Blackrock Market       53.301113        -6.178116
# 115                            Starbucks       53.302242        -6.179061
# 120               Blackrock Dart Station       53.302744        -6.178733
# 122            Blackrock Shopping Centre       53.301910        -6.179778
# 123                             Insomnia       53.301290        -6.177311
# 125                            Cafe Java       53.301620        -6.177746
# 127             Frascati Shopping Centre       53.301015        -6.181362
# 132              Williamstown Playground       53.308734        -6.195854
# 134             Booterstown DART Station       53.310137        -6.195415
# 141                 The Corner Note Cafe       53.277332        -6.102970
# 144                            Mugs Café       53.278284        -6.107267
# 151                            Idlewilde       53.277598        -6.103639
# 167                    The Sunshine Cafe       53.293813        -6.139643
# 171                 Two Beans Coffee Bar       53.294561        -6.141437
# 173                            White Tea       53.291664        -6.134640
# 175                     Harry's Cafe Bar       53.291617        -6.134593
# 176  National Maritime Museum of Ireland       53.292274        -6.131810
# 187                            Starbucks       53.293766        -6.134845
# 188                             Insomnia       53.294211        -6.133665
# 191                            Starbucks       53.293019        -6.139216
# 193                              Penneys       53.292905        -6.136838
# 194                         Gourmet Cafe       53.292539        -6.136532
# 195                            Starbucks       53.293766        -6.134824
# 197                      Leonardo Coffee       53.290530        -6.132157
# 203                     Missy Moops Cafe       53.289864        -6.130340
# 207                        Farmer Browns       53.337260        -6.231864
# 211                    Juniors Deli Cafe       53.337160        -6.234223
# 214                           Press Cafe       53.335058        -6.235269
# 215                             Foodgame       53.337452        -6.234235
# 218                National Print Museum       53.335104        -6.235390
# 220                 Mink Hand & Foot Spa       53.331372        -6.231527
# 226          Lansdowne Road DART Station       53.333999        -6.228834
# 231               Butlers Chocolate Café       53.331528        -6.232009
# 234           Third Floor Espresso (3FE)       53.339865        -6.242132
# 236                     Grand Canal Dock       53.342609        -6.239362
# 239                    The Art of Coffee       53.342185        -6.238798
# 244                    Juniors Deli Cafe       53.337160        -6.234223
# 245                             Foodgame       53.337452        -6.234235
# 246                   Grand Canal Square       53.343901        -6.238462
# 248                        Pearse Square       53.343367        -6.241793
# 258                             Flavours       53.340636        -6.236029
# 261                            Init Yoga       53.341596        -6.231675
# 267                              Annie's       53.338078        -6.236510
# 268                           KC Peaches       53.342681        -6.240314
# 269               Angel Park Café & Deli       53.339326        -6.245574
# 277                             Insomnia       53.340172        -6.236523
# 279     Grand Canal Dock Railway Station       53.339532        -6.237297
# 283             Killiney Railway Station       53.255588        -6.113045
# 0                      Bray Daly Station       53.204520        -6.100993
# 1                 Seapoint Train Station       53.299106        -6.165473
# 2                         Pearse Station       53.343327        -6.248315
# 3                      Shankhill Station       53.236508        -6.117142
# 4                     Glenageary Station       53.281183        -6.123090
# 5                  Dun Laoghaire Station       53.294900        -6.134548
# 6                         Dalkey Station       53.275800        -6.103300
#
#          venue_category
# 0        Science Museum
# 3           Coffee Shop
# 4           Coffee Shop
# 7           Coffee Shop
# 11           Art Museum
# 12          Coffee Shop
# 14                 Café
# 17                 Café
# 18                Plaza
# 28                 Café
# 30          Coffee Shop
# 31       Sandwich Place
# 32          Coffee Shop
# 33        Train Station
# 34           Waterfront
# 40          Coffee Shop
# 45        Shopping Mall
# 52                 Café
# 55   Light Rail Station
# 68        Train Station
# 70          Coffee Shop
# 80                 Café
# 81                 Café
# 83          Coffee Shop
# 84          Coffee Shop
# 86        Train Station
# 88           Playground
# 93                 Café
# 101       Train Station
# 105         Coffee Shop
# 107                Café
# 110    Department Store
# 113                Café
# 114         Flea Market
# 115         Coffee Shop
# 120       Train Station
# 122       Shopping Mall
# 123         Coffee Shop
# 125                Café
# 127       Shopping Mall
# 132          Playground
# 134       Train Station
# 141                Café
# 144         Coffee Shop
# 151                Café
# 167                Café
# 171         Coffee Shop
# 173                Café
# 175                Café
# 176              Museum
# 187         Coffee Shop
# 188         Coffee Shop
# 191         Coffee Shop
# 193      Clothing Store
# 194                Café
# 195         Coffee Shop
# 197         Coffee Shop
# 203         Coffee Shop
# 207                Café
# 211                Café
# 214                Café
# 215                Café
# 218              Museum
# 220          Nail Salon
# 226       Train Station
# 231                Café
# 234         Coffee Shop
# 236               Plaza
# 239         Coffee Shop
# 244                Café
# 245                Café
# 246               Plaza
# 248               Plaza
# 258      Sandwich Place
# 261         Yoga Studio
# 267                Café
# 268                Café
# 269                Café
# 277         Coffee Shop
# 279       Train Station
# 283       Train Station
# 0         Train Station
# 1         Train Station
# 2         Train Station
# 3         Train Station
# 4         Train Station
# 5         Train Station
# 6         Train Station

# %% [markdown]
# Now we can produce our first visual display of these businesses and areas which will make things much easier for identifying the most ideal locations to set up our business.

# %%
# create map of Dublin venues using latitude and longitude values

map_venues = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for city, lat, lng in zip (dub3['venue'], dub3['venue_latitude'], dub3['venue_longitude']):
    label = '{}'.format(city)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_venues)  
    
map_venues
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# We can now also group this data by the number of businesses per station location, telling us easily which locations we might want to avoid (large volume of cafes at one location) and which ones we are more likely to consider (fewer volume).

# %%
# Print venue type, group by Station

dub_grouped = dub3.groupby(['station', 'venue_category']).size().to_frame('size').reset_index().sort_values(['station', 'size'], ascending=[True, False])
dub_grouped
# Out:
#                              station      venue_category  size
# 0                 Blackrock , Dublin                Café     3
# 1                 Blackrock , Dublin         Coffee Shop     3
# 4                 Blackrock , Dublin       Shopping Mall     2
# 2                 Blackrock , Dublin    Department Store     1
# 3                 Blackrock , Dublin         Flea Market     1
# 5                 Blackrock , Dublin       Train Station     1
# 6               Booterstown , Dublin          Playground     1
# 7               Booterstown , Dublin       Train Station     1
# 8                       Bray, Dublin       Train Station     1
# 9                    Dalkey , Dublin                Café     2
# 10                   Dalkey , Dublin         Coffee Shop     1
# 11                    Dalkey, Dublin       Train Station     1
# 14            Dun Laoghaire , Dublin         Coffee Shop     7
# 12            Dun Laoghaire , Dublin                Café     4
# 13            Dun Laoghaire , Dublin      Clothing Store     1
# 15            Dun Laoghaire , Dublin              Museum     1
# 16             Dun Laoghaire, Dublin       Train Station     1
# 17               Glenageary , Dublin       Train Station     1
# 18                Glenageary, Dublin       Train Station     1
# 19         Grand Canal Dock , Dublin                Café     5
# 20         Grand Canal Dock , Dublin         Coffee Shop     3
# 21         Grand Canal Dock , Dublin               Plaza     3
# 22         Grand Canal Dock , Dublin      Sandwich Place     1
# 23         Grand Canal Dock , Dublin       Train Station     1
# 24         Grand Canal Dock , Dublin         Yoga Studio     1
# 25                 Killiney , Dublin       Train Station     1
# 26           Lansdowne Road , Dublin                Café     5
# 27           Lansdowne Road , Dublin              Museum     1
# 28           Lansdowne Road , Dublin          Nail Salon     1
# 29           Lansdowne Road , Dublin       Train Station     1
# 32                   Pearse , Dublin         Coffee Shop     5
# 31                   Pearse , Dublin                Café     3
# 30                   Pearse , Dublin          Art Museum     1
# 33                   Pearse , Dublin               Plaza     1
# 34                   Pearse , Dublin      Sandwich Place     1
# 35                   Pearse , Dublin      Science Museum     1
# 36                    Pearse, Dublin       Train Station     1
# 37   Salthill and Monkstown , Dublin                Café     1
# 38   Salthill and Monkstown , Dublin       Train Station     1
# 40  Sandycove and Glasthule , Dublin         Coffee Shop     3
# 39  Sandycove and Glasthule , Dublin                Café     2
# 41  Sandycove and Glasthule , Dublin          Playground     1
# 42  Sandycove and Glasthule , Dublin       Train Station     1
# 43               Sandymount , Dublin                Café     1
# 44               Sandymount , Dublin  Light Rail Station     1
# 45                  Seapoint, Dublin       Train Station     1
# 46                 Shankhill, Dublin       Train Station     1
# 47                 Shankill , Dublin         Coffee Shop     1
# 48                 Shankill , Dublin       Shopping Mall     1
# 49            Sydney Parade , Dublin         Coffee Shop     1
# 50            Sydney Parade , Dublin       Train Station     1
# 51            Sydney Parade , Dublin          Waterfront     1

# %% [markdown]
# We can use **one hot encoding** to analyze the area around each station in more detail, taking the mean of the frequency of occurrence of each venue.

# %%
# one hot encoding
dublin_onehot = pd.get_dummies(dub3[['venue_category']], prefix="", prefix_sep="")

# add station column back to dataframe
dublin_onehot['Station'] = dub3['station'] 

# move station column to the first column
fixed_columns = [dublin_onehot.columns[-1]] + list(dublin_onehot.columns[:-1])
dublin_onehot = dublin_onehot[fixed_columns]

dublin_grouped = dublin_onehot.groupby('Station').mean().reset_index()
dublin_grouped
# Out:
#                              Station  Art Museum      Café  Clothing Store  \
# 0                 Blackrock , Dublin    0.000000  0.272727        0.000000
# 1               Booterstown , Dublin    0.000000  0.000000        0.000000
# 2                       Bray, Dublin    0.000000  0.000000        0.000000
# 3                    Dalkey , Dublin    0.000000  0.666667        0.000000
# 4                     Dalkey, Dublin    0.000000  0.000000        0.000000
# 5             Dun Laoghaire , Dublin    0.000000  0.307692        0.076923
# 6              Dun Laoghaire, Dublin    0.000000  0.000000        0.000000
# 7                Glenageary , Dublin    0.000000  0.000000        0.000000
# 8                 Glenageary, Dublin    0.000000  0.000000        0.000000
# 9          Grand Canal Dock , Dublin    0.000000  0.357143        0.000000
# 10                 Killiney , Dublin    0.000000  0.000000        0.000000
# 11           Lansdowne Road , Dublin    0.000000  0.625000        0.000000
# 12                   Pearse , Dublin    0.083333  0.250000        0.000000
# 13                    Pearse, Dublin    0.000000  0.000000        0.000000
# 14   Salthill and Monkstown , Dublin    0.000000  0.500000        0.000000
# 15  Sandycove and Glasthule , Dublin    0.000000  0.285714        0.000000
# 16               Sandymount , Dublin    0.000000  0.500000        0.000000
# 17                  Seapoint, Dublin    0.000000  0.000000        0.000000
# 18                 Shankhill, Dublin    0.000000  0.000000        0.000000
# 19                 Shankill , Dublin    0.000000  0.000000        0.000000
# 20            Sydney Parade , Dublin    0.000000  0.000000        0.000000
#
#     Coffee Shop  Department Store  Flea Market  Light Rail Station    Museum  \
# 0      0.272727          0.090909     0.090909                 0.0  0.000000
# 1      0.000000          0.000000     0.000000                 0.0  0.000000
# 2      0.000000          0.000000     0.000000                 0.0  0.000000
# 3      0.333333          0.000000     0.000000                 0.0  0.000000
# 4      0.000000          0.000000     0.000000                 0.0  0.000000
# 5      0.538462          0.000000     0.000000                 0.0  0.076923
# 6      0.000000          0.000000     0.000000                 0.0  0.000000
# 7      0.000000          0.000000     0.000000                 0.0  0.000000
# 8      0.000000          0.000000     0.000000                 0.0  0.000000
# 9      0.214286          0.000000     0.000000                 0.0  0.000000
# 10     0.000000          0.000000     0.000000                 0.0  0.000000
# 11     0.000000          0.000000     0.000000                 0.0  0.125000
# 12     0.416667          0.000000     0.000000                 0.0  0.000000
# 13     0.000000          0.000000     0.000000                 0.0  0.000000
# 14     0.000000          0.000000     0.000000                 0.0  0.000000
# 15     0.428571          0.000000     0.000000                 0.0  0.000000
# 16     0.000000          0.000000     0.000000                 0.5  0.000000
# 17     0.000000          0.000000     0.000000                 0.0  0.000000
# 18     0.000000          0.000000     0.000000                 0.0  0.000000
# 19     0.500000          0.000000     0.000000                 0.0  0.000000
# 20     0.333333          0.000000     0.000000                 0.0  0.000000
#
#     Nail Salon  Playground     Plaza  Sandwich Place  Science Museum  \
# 0        0.000    0.000000  0.000000        0.000000        0.000000
# 1        0.000    0.500000  0.000000        0.000000        0.000000
# 2        0.000    0.000000  0.000000        0.000000        0.000000
# 3        0.000    0.000000  0.000000        0.000000        0.000000
# 4        0.000    0.000000  0.000000        0.000000        0.000000
# 5        0.000    0.000000  0.000000        0.000000        0.000000
# 6        0.000    0.000000  0.000000        0.000000        0.000000
# 7        0.000    0.000000  0.000000        0.000000        0.000000
# 8        0.000    0.000000  0.000000        0.000000        0.000000
# 9        0.000    0.000000  0.214286        0.071429        0.000000
# 10       0.000    0.000000  0.000000        0.000000        0.000000
# 11       0.125    0.000000  0.000000        0.000000        0.000000
# 12       0.000    0.000000  0.083333        0.083333        0.083333
# 13       0.000    0.000000  0.000000        0.000000        0.000000
# 14       0.000    0.000000  0.000000        0.000000        0.000000
# 15       0.000    0.142857  0.000000        0.000000        0.000000
# 16       0.000    0.000000  0.000000        0.000000        0.000000
# 17       0.000    0.000000  0.000000        0.000000        0.000000
# 18       0.000    0.000000  0.000000        0.000000        0.000000
# 19       0.000    0.000000  0.000000        0.000000        0.000000
# 20       0.000    0.000000  0.000000        0.000000        0.000000
#
#     Shopping Mall  Train Station  Waterfront  Yoga Studio
# 0        0.181818       0.090909    0.000000     0.000000
# 1        0.000000       0.500000    0.000000     0.000000
# 2        0.000000       1.000000    0.000000     0.000000
# 3        0.000000       0.000000    0.000000     0.000000
# 4        0.000000       1.000000    0.000000     0.000000
# 5        0.000000       0.000000    0.000000     0.000000
# 6        0.000000       1.000000    0.000000     0.000000
# 7        0.000000       1.000000    0.000000     0.000000
# 8        0.000000       1.000000    0.000000     0.000000
# 9        0.000000       0.071429    0.000000     0.071429
# 10       0.000000       1.000000    0.000000     0.000000
# 11       0.000000       0.125000    0.000000     0.000000
# 12       0.000000       0.000000    0.000000     0.000000
# 13       0.000000       1.000000    0.000000     0.000000
# 14       0.000000       0.500000    0.000000     0.000000
# 15       0.000000       0.142857    0.000000     0.000000
# 16       0.000000       0.000000    0.000000     0.000000
# 17       0.000000       1.000000    0.000000     0.000000
# 18       0.000000       1.000000    0.000000     0.000000
# 19       0.500000       0.000000    0.000000     0.000000
# 20       0.000000       0.333333    0.333333     0.000000

# %% [markdown]
# Let's print each area along with the top 5 most common venues:

# %%
# Print top 5 venues per area based on mean figure calculated above

num_top_venues = 5

for area in dublin_grouped['Station']:
    print("----"+area+"----")
    temp = dublin_grouped[dublin_grouped['Station'] == area].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Blackrock , Dublin----
#               venue  freq
# 0       Coffee Shop  0.27
# 1              Café  0.27
# 2     Shopping Mall  0.18
# 3  Department Store  0.09
# 4       Flea Market  0.09
#
#
# ----Booterstown , Dublin----
#            venue  freq
# 0     Playground   0.5
# 1  Train Station   0.5
# 2     Art Museum   0.0
# 3     Waterfront   0.0
# 4  Shopping Mall   0.0
#
#
# ----Bray, Dublin----
#            venue  freq
# 0  Train Station   1.0
# 1     Art Museum   0.0
# 2     Playground   0.0
# 3     Waterfront   0.0
# 4  Shopping Mall   0.0
#
#
# ----Dalkey , Dublin----
#          venue  freq
# 0         Café  0.67
# 1  Coffee Shop  0.33
# 2   Art Museum  0.00
# 3        Plaza  0.00
# 4   Waterfront  0.00
#
#
# ----Dalkey, Dublin----
#            venue  freq
# 0  Train Station   1.0
# 1     Art Museum   0.0
# 2     Playground   0.0
# 3     Waterfront   0.0
# 4  Shopping Mall   0.0
#
#
# ----Dun Laoghaire , Dublin----
#             venue  freq
# 0     Coffee Shop  0.54
# 1            Café  0.31
# 2  Clothing Store  0.08
# 3          Museum  0.08
# 4      Art Museum  0.00
#
#
# ----Dun Laoghaire, Dublin----
#            venue  freq
# 0  Train Station   1.0
# 1     Art Museum   0.0
# 2     Playground   0.0
# 3     Waterfront   0.0
# 4  Shopping Mall   0.0
#
#
# ----Glenageary , Dublin----
#            venue  freq
# 0  Train Station   1.0
# 1     Art Museum   0.0
# 2     Playground   0.0
# 3     Waterfront   0.0
# 4  Shopping Mall   0.0
#
#
# ----Glenageary, Dublin----
#            venue  freq
# 0  Train Station   1.0
# 1     Art Museum   0.0
# 2     Playground   0.0
# 3     Waterfront   0.0
# 4  Shopping Mall   0.0
#
#
# ----Grand Canal Dock , Dublin----
#            venue  freq
# 0           Café  0.36
# 1          Plaza  0.21
# 2    Coffee Shop  0.21
# 3    Yoga Studio  0.07
# 4  Train Station  0.07
#
#
# ----Killiney , Dublin----
#            venue  freq
# 0  Train Station   1.0
# 1     Art Museum   0.0
# 2     Playground   0.0
# 3     Waterfront   0.0
# 4  Shopping Mall   0.0
#
#
# ----Lansdowne Road , Dublin----
#            venue  freq
# 0           Café  0.62
# 1     Nail Salon  0.12
# 2  Train Station  0.12
# 3         Museum  0.12
# 4          Plaza  0.00
#
#
# ----Pearse , Dublin----
#             venue  freq
# 0     Coffee Shop  0.42
# 1            Café  0.25
# 2      Art Museum  0.08
# 3           Plaza  0.08
# 4  Science Museum  0.08
#
#
# ----Pearse, Dublin----
#            venue  freq
# 0  Train Station   1.0
# 1     Art Museum   0.0
# 2     Playground   0.0
# 3     Waterfront   0.0
# 4  Shopping Mall   0.0
#
#
# ----Salthill and Monkstown , Dublin----
#            venue  freq
# 0  Train Station   0.5
# 1           Café   0.5
# 2     Art Museum   0.0
# 3     Playground   0.0
# 4     Waterfront   0.0
#
#
# ----Sandycove and Glasthule , Dublin----
#            venue  freq
# 0    Coffee Shop  0.43
# 1           Café  0.29
# 2  Train Station  0.14
# 3     Playground  0.14
# 4     Art Museum  0.00
#
#
# ----Sandymount , Dublin----
#                 venue  freq
# 0  Light Rail Station   0.5
# 1                Café   0.5
# 2          Art Museum   0.0
# 3               Plaza   0.0
# 4          Waterfront   0.0
#
#
# ----Seapoint, Dublin----
#            venue  freq
# 0  Train Station   1.0
# 1     Art Museum   0.0
# 2     Playground   0.0
# 3     Waterfront   0.0
# 4  Shopping Mall   0.0
#
#
# ----Shankhill, Dublin----
#            venue  freq
# 0  Train Station   1.0
# 1     Art Museum   0.0
# 2     Playground   0.0
# 3     Waterfront   0.0
# 4  Shopping Mall   0.0
#
#
# ----Shankill , Dublin----
#            venue  freq
# 0    Coffee Shop   0.5
# 1  Shopping Mall   0.5
# 2     Art Museum   0.0
# 3     Playground   0.0
# 4     Waterfront   0.0
#
#
# ----Sydney Parade , Dublin----
#            venue  freq
# 0     Waterfront  0.33
# 1    Coffee Shop  0.33
# 2  Train Station  0.33
# 3     Art Museum  0.00
# 4     Playground  0.00

# %%
# Sort venues in descending order

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each area.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Station']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
stations_venues_sorted = pd.DataFrame(columns=columns)
stations_venues_sorted['Station'] = dublin_grouped['Station']

for ind in np.arange(dublin_grouped.shape[0]):
    stations_venues_sorted.iloc[ind, 1:] = return_most_common_venues(dublin_grouped.iloc[ind, :], num_top_venues)

#stations_venues_sorted.drop_duplicates()
stations_venues_sorted.head(17)
# Out:
#                              Station 1st Most Common Venue  \
# 0                 Blackrock , Dublin                  Café
# 1               Booterstown , Dublin         Train Station
# 2                       Bray, Dublin         Train Station
# 3                    Dalkey , Dublin                  Café
# 4                     Dalkey, Dublin         Train Station
# 5             Dun Laoghaire , Dublin           Coffee Shop
# 6              Dun Laoghaire, Dublin         Train Station
# 7                Glenageary , Dublin         Train Station
# 8                 Glenageary, Dublin         Train Station
# 9          Grand Canal Dock , Dublin                  Café
# 10                 Killiney , Dublin         Train Station
# 11           Lansdowne Road , Dublin                  Café
# 12                   Pearse , Dublin           Coffee Shop
# 13                    Pearse, Dublin         Train Station
# 14   Salthill and Monkstown , Dublin         Train Station
# 15  Sandycove and Glasthule , Dublin           Coffee Shop
# 16               Sandymount , Dublin                  Café
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0            Coffee Shop         Shopping Mall         Train Station
# 1             Playground           Yoga Studio    Light Rail Station
# 2            Yoga Studio                Museum                  Café
# 3            Coffee Shop           Yoga Studio                Museum
# 4            Yoga Studio                Museum                  Café
# 5                   Café                Museum        Clothing Store
# 6            Yoga Studio                Museum                  Café
# 7            Yoga Studio                Museum                  Café
# 8            Yoga Studio                Museum                  Café
# 9                  Plaza           Coffee Shop           Yoga Studio
# 10           Yoga Studio                Museum                  Café
# 11            Nail Salon                Museum         Train Station
# 12                  Café            Art Museum        Science Museum
# 13           Yoga Studio                Museum                  Café
# 14                  Café           Yoga Studio                Museum
# 15                  Café         Train Station            Playground
# 16    Light Rail Station           Yoga Studio                Museum
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0       Department Store           Flea Market           Yoga Studio
# 1                   Café        Clothing Store           Coffee Shop
# 2         Clothing Store           Coffee Shop      Department Store
# 3         Clothing Store      Department Store           Flea Market
# 4         Clothing Store           Coffee Shop      Department Store
# 5            Yoga Studio      Department Store           Flea Market
# 6         Clothing Store           Coffee Shop      Department Store
# 7         Clothing Store           Coffee Shop      Department Store
# 8         Clothing Store           Coffee Shop      Department Store
# 9          Train Station        Sandwich Place    Light Rail Station
# 10        Clothing Store           Coffee Shop      Department Store
# 11        Clothing Store           Coffee Shop      Department Store
# 12        Sandwich Place                 Plaza    Light Rail Station
# 13        Clothing Store           Coffee Shop      Department Store
# 14        Clothing Store           Coffee Shop      Department Store
# 15           Yoga Studio    Light Rail Station        Clothing Store
# 16        Clothing Store           Coffee Shop      Department Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0     Light Rail Station        Clothing Store             Nail Salon
# 1       Department Store           Flea Market             Nail Salon
# 2            Flea Market    Light Rail Station             Nail Salon
# 3     Light Rail Station            Nail Salon             Waterfront
# 4            Flea Market    Light Rail Station             Nail Salon
# 5     Light Rail Station            Nail Salon             Waterfront
# 6            Flea Market    Light Rail Station             Nail Salon
# 7            Flea Market    Light Rail Station             Nail Salon
# 8            Flea Market    Light Rail Station             Nail Salon
# 9         Clothing Store      Department Store            Flea Market
# 10           Flea Market    Light Rail Station             Nail Salon
# 11           Flea Market    Light Rail Station            Yoga Studio
# 12        Clothing Store      Department Store            Flea Market
# 13           Flea Market    Light Rail Station             Nail Salon
# 14           Flea Market    Light Rail Station             Nail Salon
# 15      Department Store           Flea Market             Nail Salon
# 16           Flea Market            Nail Salon             Waterfront

# %% [markdown]
# ### Clustering of Stations
#
# The next step in the analysis is to perform clustering of our stations, so we can easily see the main clusters we want to explore.

# %%
# set number of clusters
kclusters = 5

dublin_clustering = dublin_grouped.drop('Station', 1)
dublin_clustering

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(dublin_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 3, 1, 0, 1, 2, 1, 1, 1, 2], dtype=int32)

# %%
# add clustering labels
stations_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
dublin_merged = dub3

# merge dublin_grouped with dublin_data to add latitude/longitude for each neighborhood
dublin_merged = dublin_merged.join(stations_venues_sorted.set_index('Station'), on='station')

dublin_merged.head(5)
# Out:
#             station  station_latitude  station_longitude  \
# 0   Pearse , Dublin         53.343335          -6.248463
# 3   Pearse , Dublin         53.343335          -6.248463
# 4   Pearse , Dublin         53.343335          -6.248463
# 7   Pearse , Dublin         53.343335          -6.248463
# 11  Pearse , Dublin         53.343335          -6.248463
#
#                           venue  venue_latitude  venue_longitude  \
# 0               Science Gallery       53.344186        -6.250524
# 3          Science Gallery Café       53.344348        -6.250779
# 4                 Honey Truffle       53.344089        -6.248893
# 7          Arabica Coffee House       53.343676        -6.247063
# 11  National Gallery of Ireland       53.341558        -6.252528
#
#     venue_category  Cluster Labels 1st Most Common Venue  \
# 0   Science Museum               2           Coffee Shop
# 3      Coffee Shop               2           Coffee Shop
# 4      Coffee Shop               2           Coffee Shop
# 7      Coffee Shop               2           Coffee Shop
# 11      Art Museum               2           Coffee Shop
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Café            Art Museum        Science Museum
# 3                   Café            Art Museum        Science Museum
# 4                   Café            Art Museum        Science Museum
# 7                   Café            Art Museum        Science Museum
# 11                  Café            Art Museum        Science Museum
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0         Sandwich Place                 Plaza    Light Rail Station
# 3         Sandwich Place                 Plaza    Light Rail Station
# 4         Sandwich Place                 Plaza    Light Rail Station
# 7         Sandwich Place                 Plaza    Light Rail Station
# 11        Sandwich Place                 Plaza    Light Rail Station
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0         Clothing Store      Department Store            Flea Market
# 3         Clothing Store      Department Store            Flea Market
# 4         Clothing Store      Department Store            Flea Market
# 7         Clothing Store      Department Store            Flea Market
# 11        Clothing Store      Department Store            Flea Market

# %%
# Remove unwanted columns for clustering process

df1 = dublin_merged.drop('venue', 1)
df2 = df1.drop('venue_category', 1)

df3 = df2.drop('venue_latitude', 1)
df4 = df3.drop('venue_longitude', 1)

df4 = df4.drop_duplicates().reset_index()

df4
# Out:
#     index                           station  station_latitude  \
# 0       0                   Pearse , Dublin         53.343335
# 1      32            Sydney Parade , Dublin         53.320787
# 2      40                 Shankill , Dublin         53.230228
# 3      52               Sandymount , Dublin         53.327928
# 4      68               Glenageary , Dublin         53.281238
# 5      70  Sandycove and Glasthule , Dublin         53.288252
# 6      93   Salthill and Monkstown , Dublin         53.295391
# 7     105                Blackrock , Dublin         53.301864
# 8     132              Booterstown , Dublin         53.308629
# 9     141                   Dalkey , Dublin         53.275624
# 10    167            Dun Laoghaire , Dublin         53.292279
# 11    207           Lansdowne Road , Dublin         53.335233
# 12    234         Grand Canal Dock , Dublin         53.339819
# 13    283                 Killiney , Dublin         53.255384
# 14      0                      Bray, Dublin         53.204520
# 15      1                  Seapoint, Dublin         53.299106
# 16      2                    Pearse, Dublin         53.343327
# 17      3                 Shankhill, Dublin         53.236508
# 18      4                Glenageary, Dublin         53.281183
# 19      5             Dun Laoghaire, Dublin         53.294900
# 20      6                    Dalkey, Dublin         53.275800
#
#     station_longitude  Cluster Labels 1st Most Common Venue  \
# 0           -6.248463               2           Coffee Shop
# 1           -6.211552               2         Train Station
# 2           -6.124181               4         Shopping Mall
# 3           -6.221050               0                  Café
# 4           -6.123108               1         Train Station
# 5           -6.127045               2           Coffee Shop
# 6           -6.152424               0         Train Station
# 7           -6.178834               2                  Café
# 8           -6.196652               3         Train Station
# 9           -6.103204               0                  Café
# 10          -6.136008               2           Coffee Shop
# 11          -6.228178               0                  Café
# 12          -6.238188               2                  Café
# 13          -6.113040               1         Train Station
# 14          -6.100993               1         Train Station
# 15          -6.165473               1         Train Station
# 16          -6.248315               1         Train Station
# 17          -6.117142               1         Train Station
# 18          -6.123090               1         Train Station
# 19          -6.134548               1         Train Station
# 20          -6.103300               1         Train Station
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Café            Art Museum        Science Museum
# 1            Coffee Shop            Waterfront           Yoga Studio
# 2            Coffee Shop           Yoga Studio                Museum
# 3     Light Rail Station           Yoga Studio                Museum
# 4            Yoga Studio                Museum                  Café
# 5                   Café         Train Station            Playground
# 6                   Café           Yoga Studio                Museum
# 7            Coffee Shop         Shopping Mall         Train Station
# 8             Playground           Yoga Studio    Light Rail Station
# 9            Coffee Shop           Yoga Studio                Museum
# 10                  Café                Museum        Clothing Store
# 11            Nail Salon                Museum         Train Station
# 12                 Plaza           Coffee Shop           Yoga Studio
# 13           Yoga Studio                Museum                  Café
# 14           Yoga Studio                Museum                  Café
# 15           Yoga Studio                Museum                  Café
# 16           Yoga Studio                Museum                  Café
# 17           Yoga Studio                Museum                  Café
# 18           Yoga Studio                Museum                  Café
# 19           Yoga Studio                Museum                  Café
# 20           Yoga Studio                Museum                  Café
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0         Sandwich Place                 Plaza    Light Rail Station
# 1     Light Rail Station                  Café        Clothing Store
# 2                   Café        Clothing Store      Department Store
# 3         Clothing Store           Coffee Shop      Department Store
# 4         Clothing Store           Coffee Shop      Department Store
# 5            Yoga Studio    Light Rail Station        Clothing Store
# 6         Clothing Store           Coffee Shop      Department Store
# 7       Department Store           Flea Market           Yoga Studio
# 8                   Café        Clothing Store           Coffee Shop
# 9         Clothing Store      Department Store           Flea Market
# 10           Yoga Studio      Department Store           Flea Market
# 11        Clothing Store           Coffee Shop      Department Store
# 12         Train Station        Sandwich Place    Light Rail Station
# 13        Clothing Store           Coffee Shop      Department Store
# 14        Clothing Store           Coffee Shop      Department Store
# 15        Clothing Store           Coffee Shop      Department Store
# 16        Clothing Store           Coffee Shop      Department Store
# 17        Clothing Store           Coffee Shop      Department Store
# 18        Clothing Store           Coffee Shop      Department Store
# 19        Clothing Store           Coffee Shop      Department Store
# 20        Clothing Store           Coffee Shop      Department Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0         Clothing Store      Department Store            Flea Market
# 1       Department Store           Flea Market             Nail Salon
# 2            Flea Market    Light Rail Station             Nail Salon
# 3            Flea Market            Nail Salon             Waterfront
# 4            Flea Market    Light Rail Station             Nail Salon
# 5       Department Store           Flea Market             Nail Salon
# 6            Flea Market    Light Rail Station             Nail Salon
# 7     Light Rail Station        Clothing Store             Nail Salon
# 8       Department Store           Flea Market             Nail Salon
# 9     Light Rail Station            Nail Salon             Waterfront
# 10    Light Rail Station            Nail Salon             Waterfront
# 11           Flea Market    Light Rail Station            Yoga Studio
# 12        Clothing Store      Department Store            Flea Market
# 13           Flea Market    Light Rail Station             Nail Salon
# 14           Flea Market    Light Rail Station             Nail Salon
# 15           Flea Market    Light Rail Station             Nail Salon
# 16           Flea Market    Light Rail Station             Nail Salon
# 17           Flea Market    Light Rail Station             Nail Salon
# 18           Flea Market    Light Rail Station             Nail Salon
# 19           Flea Market    Light Rail Station             Nail Salon
# 20           Flea Market    Light Rail Station             Nail Salon

# %% [markdown]
# Now let's create a map with these clusters.

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(df4['station_latitude'], df4['station_longitude'], df4['station'], df4['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        #color=rainbow[cluster-1],
        fill=True,
        #fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df4.head()
# Out:
#    index                 station  station_latitude  station_longitude  \
# 0      0         Pearse , Dublin         53.343335          -6.248463
# 1     32  Sydney Parade , Dublin         53.320787          -6.211552
# 2     40       Shankill , Dublin         53.230228          -6.124181
# 3     52     Sandymount , Dublin         53.327928          -6.221050
# 4     68     Glenageary , Dublin         53.281238          -6.123108
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               2           Coffee Shop                  Café
# 1               2         Train Station           Coffee Shop
# 2               4         Shopping Mall           Coffee Shop
# 3               0                  Café    Light Rail Station
# 4               1         Train Station           Yoga Studio
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0            Art Museum        Science Museum        Sandwich Place
# 1            Waterfront           Yoga Studio    Light Rail Station
# 2           Yoga Studio                Museum                  Café
# 3           Yoga Studio                Museum        Clothing Store
# 4                Museum                  Café        Clothing Store
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                 Plaza    Light Rail Station        Clothing Store
# 1                  Café        Clothing Store      Department Store
# 2        Clothing Store      Department Store           Flea Market
# 3           Coffee Shop      Department Store           Flea Market
# 4           Coffee Shop      Department Store           Flea Market
#
#   9th Most Common Venue 10th Most Common Venue
# 0      Department Store            Flea Market
# 1           Flea Market             Nail Salon
# 2    Light Rail Station             Nail Salon
# 3            Nail Salon             Waterfront
# 4    Light Rail Station             Nail Salon

# %%
# Remove duplicate rows from df4

df4 = df4.drop_duplicates().reset_index()
df4
# Out:
#     level_0  index                           station  station_latitude  \
# 0         0      0                   Pearse , Dublin         53.343335
# 1         1     32            Sydney Parade , Dublin         53.320787
# 2         2     40                 Shankill , Dublin         53.230228
# 3         3     52               Sandymount , Dublin         53.327928
# 4         4     68               Glenageary , Dublin         53.281238
# 5         5     70  Sandycove and Glasthule , Dublin         53.288252
# 6         6     93   Salthill and Monkstown , Dublin         53.295391
# 7         7    105                Blackrock , Dublin         53.301864
# 8         8    132              Booterstown , Dublin         53.308629
# 9         9    141                   Dalkey , Dublin         53.275624
# 10       10    167            Dun Laoghaire , Dublin         53.292279
# 11       11    207           Lansdowne Road , Dublin         53.335233
# 12       12    234         Grand Canal Dock , Dublin         53.339819
# 13       13    283                 Killiney , Dublin         53.255384
# 14       14      0                      Bray, Dublin         53.204520
# 15       15      1                  Seapoint, Dublin         53.299106
# 16       16      2                    Pearse, Dublin         53.343327
# 17       17      3                 Shankhill, Dublin         53.236508
# 18       18      4                Glenageary, Dublin         53.281183
# 19       19      5             Dun Laoghaire, Dublin         53.294900
# 20       20      6                    Dalkey, Dublin         53.275800
#
#     station_longitude  Cluster Labels 1st Most Common Venue  \
# 0           -6.248463               2           Coffee Shop
# 1           -6.211552               2         Train Station
# 2           -6.124181               4         Shopping Mall
# 3           -6.221050               0                  Café
# 4           -6.123108               1         Train Station
# 5           -6.127045               2           Coffee Shop
# 6           -6.152424               0         Train Station
# 7           -6.178834               2                  Café
# 8           -6.196652               3         Train Station
# 9           -6.103204               0                  Café
# 10          -6.136008               2           Coffee Shop
# 11          -6.228178               0                  Café
# 12          -6.238188               2                  Café
# 13          -6.113040               1         Train Station
# 14          -6.100993               1         Train Station
# 15          -6.165473               1         Train Station
# 16          -6.248315               1         Train Station
# 17          -6.117142               1         Train Station
# 18          -6.123090               1         Train Station
# 19          -6.134548               1         Train Station
# 20          -6.103300               1         Train Station
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Café            Art Museum        Science Museum
# 1            Coffee Shop            Waterfront           Yoga Studio
# 2            Coffee Shop           Yoga Studio                Museum
# 3     Light Rail Station           Yoga Studio                Museum
# 4            Yoga Studio                Museum                  Café
# 5                   Café         Train Station            Playground
# 6                   Café           Yoga Studio                Museum
# 7            Coffee Shop         Shopping Mall         Train Station
# 8             Playground           Yoga Studio    Light Rail Station
# 9            Coffee Shop           Yoga Studio                Museum
# 10                  Café                Museum        Clothing Store
# 11            Nail Salon                Museum         Train Station
# 12                 Plaza           Coffee Shop           Yoga Studio
# 13           Yoga Studio                Museum                  Café
# 14           Yoga Studio                Museum                  Café
# 15           Yoga Studio                Museum                  Café
# 16           Yoga Studio                Museum                  Café
# 17           Yoga Studio                Museum                  Café
# 18           Yoga Studio                Museum                  Café
# 19           Yoga Studio                Museum                  Café
# 20           Yoga Studio                Museum                  Café
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0         Sandwich Place                 Plaza    Light Rail Station
# 1     Light Rail Station                  Café        Clothing Store
# 2                   Café        Clothing Store      Department Store
# 3         Clothing Store           Coffee Shop      Department Store
# 4         Clothing Store           Coffee Shop      Department Store
# 5            Yoga Studio    Light Rail Station        Clothing Store
# 6         Clothing Store           Coffee Shop      Department Store
# 7       Department Store           Flea Market           Yoga Studio
# 8                   Café        Clothing Store           Coffee Shop
# 9         Clothing Store      Department Store           Flea Market
# 10           Yoga Studio      Department Store           Flea Market
# 11        Clothing Store           Coffee Shop      Department Store
# 12         Train Station        Sandwich Place    Light Rail Station
# 13        Clothing Store           Coffee Shop      Department Store
# 14        Clothing Store           Coffee Shop      Department Store
# 15        Clothing Store           Coffee Shop      Department Store
# 16        Clothing Store           Coffee Shop      Department Store
# 17        Clothing Store           Coffee Shop      Department Store
# 18        Clothing Store           Coffee Shop      Department Store
# 19        Clothing Store           Coffee Shop      Department Store
# 20        Clothing Store           Coffee Shop      Department Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0         Clothing Store      Department Store            Flea Market
# 1       Department Store           Flea Market             Nail Salon
# 2            Flea Market    Light Rail Station             Nail Salon
# 3            Flea Market            Nail Salon             Waterfront
# 4            Flea Market    Light Rail Station             Nail Salon
# 5       Department Store           Flea Market             Nail Salon
# 6            Flea Market    Light Rail Station             Nail Salon
# 7     Light Rail Station        Clothing Store             Nail Salon
# 8       Department Store           Flea Market             Nail Salon
# 9     Light Rail Station            Nail Salon             Waterfront
# 10    Light Rail Station            Nail Salon             Waterfront
# 11           Flea Market    Light Rail Station            Yoga Studio
# 12        Clothing Store      Department Store            Flea Market
# 13           Flea Market    Light Rail Station             Nail Salon
# 14           Flea Market    Light Rail Station             Nail Salon
# 15           Flea Market    Light Rail Station             Nail Salon
# 16           Flea Market    Light Rail Station             Nail Salon
# 17           Flea Market    Light Rail Station             Nail Salon
# 18           Flea Market    Light Rail Station             Nail Salon
# 19           Flea Market    Light Rail Station             Nail Salon
# 20           Flea Market    Light Rail Station             Nail Salon

# %% [markdown]
# Let's examine each cluster further.

# %%
cluster0 = df4.loc[df4['Cluster Labels'] == 0] 
cluster0
# Out:
#     level_0  index                          station  station_latitude  \
# 3         3     52              Sandymount , Dublin         53.327928
# 6         6     93  Salthill and Monkstown , Dublin         53.295391
# 9         9    141                  Dalkey , Dublin         53.275624
# 11       11    207          Lansdowne Road , Dublin         53.335233
#
#     station_longitude  Cluster Labels 1st Most Common Venue  \
# 3           -6.221050               0                  Café
# 6           -6.152424               0         Train Station
# 9           -6.103204               0                  Café
# 11          -6.228178               0                  Café
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 3     Light Rail Station           Yoga Studio                Museum
# 6                   Café           Yoga Studio                Museum
# 9            Coffee Shop           Yoga Studio                Museum
# 11            Nail Salon                Museum         Train Station
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 3         Clothing Store           Coffee Shop      Department Store
# 6         Clothing Store           Coffee Shop      Department Store
# 9         Clothing Store      Department Store           Flea Market
# 11        Clothing Store           Coffee Shop      Department Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 3            Flea Market            Nail Salon             Waterfront
# 6            Flea Market    Light Rail Station             Nail Salon
# 9     Light Rail Station            Nail Salon             Waterfront
# 11           Flea Market    Light Rail Station            Yoga Studio

# %%
cluster1 = df4.loc[df4['Cluster Labels'] == 1]
cluster1
# Out:
#     level_0  index                station  station_latitude  \
# 4         4     68    Glenageary , Dublin         53.281238
# 13       13    283      Killiney , Dublin         53.255384
# 14       14      0           Bray, Dublin         53.204520
# 15       15      1       Seapoint, Dublin         53.299106
# 16       16      2         Pearse, Dublin         53.343327
# 17       17      3      Shankhill, Dublin         53.236508
# 18       18      4     Glenageary, Dublin         53.281183
# 19       19      5  Dun Laoghaire, Dublin         53.294900
# 20       20      6         Dalkey, Dublin         53.275800
#
#     station_longitude  Cluster Labels 1st Most Common Venue  \
# 4           -6.123108               1         Train Station
# 13          -6.113040               1         Train Station
# 14          -6.100993               1         Train Station
# 15          -6.165473               1         Train Station
# 16          -6.248315               1         Train Station
# 17          -6.117142               1         Train Station
# 18          -6.123090               1         Train Station
# 19          -6.134548               1         Train Station
# 20          -6.103300               1         Train Station
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 4            Yoga Studio                Museum                  Café
# 13           Yoga Studio                Museum                  Café
# 14           Yoga Studio                Museum                  Café
# 15           Yoga Studio                Museum                  Café
# 16           Yoga Studio                Museum                  Café
# 17           Yoga Studio                Museum                  Café
# 18           Yoga Studio                Museum                  Café
# 19           Yoga Studio                Museum                  Café
# 20           Yoga Studio                Museum                  Café
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 4         Clothing Store           Coffee Shop      Department Store
# 13        Clothing Store           Coffee Shop      Department Store
# 14        Clothing Store           Coffee Shop      Department Store
# 15        Clothing Store           Coffee Shop      Department Store
# 16        Clothing Store           Coffee Shop      Department Store
# 17        Clothing Store           Coffee Shop      Department Store
# 18        Clothing Store           Coffee Shop      Department Store
# 19        Clothing Store           Coffee Shop      Department Store
# 20        Clothing Store           Coffee Shop      Department Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 4            Flea Market    Light Rail Station             Nail Salon
# 13           Flea Market    Light Rail Station             Nail Salon
# 14           Flea Market    Light Rail Station             Nail Salon
# 15           Flea Market    Light Rail Station             Nail Salon
# 16           Flea Market    Light Rail Station             Nail Salon
# 17           Flea Market    Light Rail Station             Nail Salon
# 18           Flea Market    Light Rail Station             Nail Salon
# 19           Flea Market    Light Rail Station             Nail Salon
# 20           Flea Market    Light Rail Station             Nail Salon

# %%
cluster2 = df4.loc[df4['Cluster Labels'] == 2] #df4.columns[[1] + list(range(5, df4.shape[1]))]]
cluster2
# Out:
#     level_0  index                           station  station_latitude  \
# 0         0      0                   Pearse , Dublin         53.343335
# 1         1     32            Sydney Parade , Dublin         53.320787
# 5         5     70  Sandycove and Glasthule , Dublin         53.288252
# 7         7    105                Blackrock , Dublin         53.301864
# 10       10    167            Dun Laoghaire , Dublin         53.292279
# 12       12    234         Grand Canal Dock , Dublin         53.339819
#
#     station_longitude  Cluster Labels 1st Most Common Venue  \
# 0           -6.248463               2           Coffee Shop
# 1           -6.211552               2         Train Station
# 5           -6.127045               2           Coffee Shop
# 7           -6.178834               2                  Café
# 10          -6.136008               2           Coffee Shop
# 12          -6.238188               2                  Café
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Café            Art Museum        Science Museum
# 1            Coffee Shop            Waterfront           Yoga Studio
# 5                   Café         Train Station            Playground
# 7            Coffee Shop         Shopping Mall         Train Station
# 10                  Café                Museum        Clothing Store
# 12                 Plaza           Coffee Shop           Yoga Studio
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0         Sandwich Place                 Plaza    Light Rail Station
# 1     Light Rail Station                  Café        Clothing Store
# 5            Yoga Studio    Light Rail Station        Clothing Store
# 7       Department Store           Flea Market           Yoga Studio
# 10           Yoga Studio      Department Store           Flea Market
# 12         Train Station        Sandwich Place    Light Rail Station
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0         Clothing Store      Department Store            Flea Market
# 1       Department Store           Flea Market             Nail Salon
# 5       Department Store           Flea Market             Nail Salon
# 7     Light Rail Station        Clothing Store             Nail Salon
# 10    Light Rail Station            Nail Salon             Waterfront
# 12        Clothing Store      Department Store            Flea Market

# %%
cluster3 = df4.loc[df4['Cluster Labels'] == 3] #df4.columns[[1] + list(range(5, df4.shape[1]))]]
cluster3
# Out:
#    level_0  index               station  station_latitude  station_longitude  \
# 8        8    132  Booterstown , Dublin         53.308629          -6.196652
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 8               3         Train Station            Playground
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 8           Yoga Studio    Light Rail Station                  Café
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 8        Clothing Store           Coffee Shop      Department Store
#
#   9th Most Common Venue 10th Most Common Venue
# 8           Flea Market             Nail Salon

# %%
cluster4 = df4.loc[df4['Cluster Labels'] == 4] #df4.columns[[1] + list(range(5, df4.shape[1]))]]
cluster4
# Out:
#    level_0  index            station  station_latitude  station_longitude  \
# 2        2     40  Shankill , Dublin         53.230228          -6.124181
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 2               4         Shopping Mall           Coffee Shop
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 2           Yoga Studio                Museum                  Café
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 2        Clothing Store      Department Store           Flea Market
#
#   9th Most Common Venue 10th Most Common Venue
# 2    Light Rail Station             Nail Salon

# %% [markdown]
# ## Results
#
# Now that we have performed our main analysis, we can start to deduce what the best locations for the business will be. Based on the maps and tables above, we will split the areas in to three sections.
#
# **1. Stations with lack of Services**
#
# Right off the bat we can omit certain areas from our area of interest. We included the three most furthest stations but they are too far away AND have very little other services around them:
#
# - Killiney
# - Shankhill
# - Bray
#
# Despite their relative distance to the centre of Dublin, the folllowing stations have no meaningful services around them so it would not be wise to place a coffee shop/cafe here. These are:
#
# - Booterstown
# - Seapoint
#
# **2. Stations with tough competition**
#
# The areas of two stations which would provide fierce competition are **Blackrock** and **Dun Laoghaire**. Despite these being built-up areas with many services, they both have a high number of coffee shops (Blackrock - 6, Dun Laoghaire - 12). Further towards the city, Pearse St and Grand Canal Dock also have tough competition and due to their proximity to the city centre, they would not satisfy the criteria of being a truly South Dublin brand, as set out in the Introduction.
#
# **3. Areas to consider**
#
# - Lansdowne Road
#
# - Sandymount
#
# - Sydney Parade
#
# - Monkstown
#
# - Sandycove & Glasthule
#
# - Dalkey
